# %%
from p1b_pandemic.lattice import SquareLattice
from p1b_pandemic.model import PandemicModel
from p1b_pandemic.scripts.percolation import parameter_scan

# %%
lattice = SquareLattice(
    dimensions=(25, 100),
    n_connections=2,
)
model = PandemicModel(
    lattice=lattice,
    vaccine_frac = 0.25,
)

# %%
model.animate(n_days=150)

# %%
import numpy as np
values = np.linspace(0.18, 0.45, 50)
parameter_scan(model, values=values, repeats=100)
# Out:
# Simulations completed:   0%|          | 0/5000 [00:00<?, ?it/s]
# Transition at 0.2722359287011544 +/- 0.0006837005776576632
# Steepness is 57.89712896869564 +/- 2.0192792872552863

# %%
lattice = SquareLattice(
    dimensions=(25, 200),
    n_connections=2,
)
model = PandemicModel(
    lattice=lattice,
    vaccine_frac = 0.25,
)
values = np.linspace(0.18, 0.45, 50)
parameter_scan(model, values=values, repeats=100)

# %%
lattice = SquareLattice(
    dimensions=(50, 200),
    n_connections=2,
)
model = PandemicModel(
    lattice=lattice,
    vaccine_frac = 0.25,
)
values = np.linspace(0.18, 0.45, 50)
parameter_scan(model, values=values, repeats=100)

# %%
lattice = SquareLattice(
    dimensions=(25, 100),
    n_connections=3,
)
model = PandemicModel(
    lattice=lattice,
    vaccine_frac = 0.25,
)
model.animate(n_days=150)

# %%
values = np.linspace(0.18, 0.45, 50)
parameter_scan(model, values=values, repeats=100)

# %%
lattice = SquareLattice(
    dimensions=(100, 100),
    n_connections=4,
)
model = PandemicModel(
    lattice=lattice,
    vaccine_frac = 0.25,
)
model.animate(n_days=150)

# %%
values = np.linspace(0.3, 0.7, 50)
parameter_scan(model, values=values, repeats=100)
